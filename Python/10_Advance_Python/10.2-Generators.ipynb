# %% [markdown]
# #### Generators
#
# Generators are a simpler way to create iterators. They use the yield keyword to produce a series of values lazily, which means they generate values on the fly and do not store them in memory.

# %%
def square(n):
    for i in range(6):
        yield i**2

# %%
square(6)
# Out:
# <generator object square at 0x000002C2B4932C20>

# %%
for i in square(6):
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %%
a=square(6)
a
# Out:
# <generator object square at 0x000002C2B4F14860>

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

# %%
gen=my_generator()
gen
# Out:
# <generator object my_generator at 0x000002C2B4F20460>

# %%
next(gen)
# Out:
# 3

# %%
for val in gen:
    print(val)

# %% [markdown]
# #### Practical Example: Reading Large Files
#
# Generators are particularly useful for reading large files because they allow you to process one line at a time without loading the entire file into memory.

# %%
### Practical : Reading LArge Files

def read_large_file(file_path):
    with open(file_path,'r',encoding='utf-8') as file:
        for line in file:
            yield line

# %%
file_path='large_file.txt'

for line in read_large_file(file_path):
    print(line.strip())
# Out:
# Smt. Droupadi Murmu was sworn in as the 15th President of India on 25 July, 2022. Previously, she was the Governor of Jharkhand from 2015 to 2021. She has devoted her life to empowering the downtrodden and the marginalised sections and deepening the democratic values.
#
# Early Life and Education
#
# Born in a Santhali tribal family on 20 June, 1958 at Uparbeda village, Mayurbhanj, Odisha, Smt. Murmu’s early life was marked by hardships and struggle. On completion of primary education from the village school, she went to Bhubaneswar on her own initiative to continue her studies. She earned the degree of Bachelor of Arts from Ramadevi Women’s College, Bhubaneswar and became the first woman from her village to receive college education.
#
# Professional Career
#
# From 1979 to 1983, Smt. Murmu served as a Junior Assistant in the Irrigation and Power Department, Government of Odisha. Later, she served as an honorary teacher at Sri Aurobindo Integral Education Centre, Rairangpur, from 1994 to 1997.
#
# Public Life
#
# In 2000, Smt. Murmu was elected from the Rairangpur constituency as a Member of the Legislative Assembly of Odisha and continued to hold the post till 2009, serving two terms. During this period, she served as Minister of State (Independent Charge), Department of Commerce and Transport in the Government of Odisha from March 6, 2000 to August 6, 2002 and as Minister of State (Independent Charge), Department of Fisheries and Animal Resources Development, Government of Odisha from Augu

# %%
def read_large_file(file_path):
    with open(file_path,'r',encoding='utf-16') as file:
        for line in file:
            yield line

# %%
file_path='D:/file_list.txt'

for line in read_large_file(file_path):
    print(line.strip())
# Out:
# Directory: D:\lms\server
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/26/2025   4:18 PM                controllers
# d-----         1/30/2025   3:46 PM                database
# d-----         3/30/2025   7:56 PM                middlewares
# d-----         3/26/2025   1:44 PM                models
# d-----         4/10/2025   9:36 PM                node_modules
# d-----         3/26/2025   2:00 PM                routes
# d-----         4/10/2025   5:30 PM                uploads
# d-----          4/4/2025   1:56 PM                utils
# -a----         4/11/2025  10:48 AM           1310 .env
# -a----         4/11/2025  11:43 AM           1196 .env.development
# -a----         4/11/2025  11:43 AM           1243 .env.production
# -a----         4/11/2025   3:31 PM              0 file_list.txt
# -a----         4/10/2025  11:03 PM           5657 index.js
# -a----         4/10/2025   9:36 PM          79777 package-lock.json
# -a----         4/11/2025  12:45 PM            726 package.json
#
#
# Directory: D:\lms\server\controllers
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/3/2025  11:57 PM           4400 batch.controller.js
# -a----         4/10/2025   3:31 PM          31728 course.controller.js
# -a----         3/17/2025   1:25 PM           4024 courseProgress.controller.js
# -a----         4/10/2025   3:32 PM          18884 coursePurchase.controller.js
# -a----         3/26/2025   4:42 PM           1402 instructor.controller.js
# -a----          4/4/2025   2:41 PM           3858 student.controller.js
# -a----         4/10/2025   3:30 PM          22398 user.controller.js
#
#
# Directory: D:\lms\server\database
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/2/2025  11:57 AM            476 db.js
#
#
# Directory: D:\lms\server\middlewares
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/1/2025   4:05 PM            915 isAdmin.js
# -a----         4/10/2025   3:29 PM           6986 isAuthenticated.js
#
#
# Directory: D:\lms\server\models
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/3/2025  11:55 PM            658 batch.model.js
# -a----         3/17/2025   1:25 PM           1017 course.model.js
# -a----         3/17/2025   1:25 PM            451 courseProgress.js
# -a----         3/17/2025   1:25 PM            705 coursePurchase.model.js
# -a----         3/26/2025   4:42 PM            394 Instructor.js
# -a----         3/24/2025   5:18 PM           1082 lecture.model.js
# -a----         3/26/2025   4:42 PM            387 Student.js
# -a----          4/4/2025   1:36 PM           1650 user.model.js
#
#
# Directory: D:\lms\server\node_modules
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         4/10/2025   5:41 PM                .bin
# d-----         1/30/2025  11:49 AM                @mongodb-js
# d-----         3/13/2025   5:27 PM                @types
# d-----         1/30/2025  11:48 AM                accepts
# d-----          4/4/2025   1:36 PM                agent-base
# d-----         1/30/2025  11:49 AM                anymatch
# d-----         2/10/2025  11:21 AM                append-field
# d-----         1/30/2025  11:48 AM                array-flatten
# d-----         3/23/2025   5:04 PM                asynckit
# d-----         3/23/2025   5:04 PM                axios
# d-----         1/30/2025  11:49 AM                balanced-match
# d-----         3/25/2025   1:40 PM                basic-auth
# d-----         1/30/2025  11:49 AM                bcryptjs
# d-----         1/30/2025  11:49 AM                binary-extensions
# d-----         1/30/2025  11:48 AM                body-parser
# d-----         1/30/2025  11:49 AM                brace-expansion
# d-----         1/30/2025  11:49 AM                braces
# d-----         1/30/2025  11:49 AM                bson
# d-----         1/30/2025  11:49 AM                buffer-equal-constant-time
# d-----         2/10/2025  11:21 AM                buffer-from
# d-----         2/10/2025  11:21 AM                busboy
# d-----         1/30/2025  11:48 AM                bytes
# d-----         1/30/2025  11:48 AM                call-bind-apply-helpers
# d-----         1/30/2025  11:48 AM                call-bound
# d-----         1/30/2025  11:49 AM                chokidar
# d-----         2/10/2025  11:32 AM                cloudinary
# d-----         3/23/2025   5:04 PM                combined-stream
# d-----         1/30/2025  11:49 AM                concat-map
# d-----         2/10/2025  11:21 AM                concat-stream
# d-----         1/30/2025  11:48 AM                content-disposition
# d-----         1/30/2025  11:48 AM                content-type
# d-----         1/30/2025  11:48 AM                cookie
# d-----         1/31/2025   1:46 PM                cookie-parser
# d-----         1/30/2025  11:48 AM                cookie-signature
# d-----         2/10/2025  11:21 AM                core-util-is
# d-----         1/30/2025  11:49 AM                cors
# d-----         4/10/2025   5:41 PM                cross-env
# d-----         4/10/2025   5:41 PM                cross-spawn
# d-----          4/4/2025   1:36 PM                dayjs
# d-----         1/30/2025  11:48 AM                debug
# d-----         3/23/2025   5:04 PM                delayed-stream
# d-----         1/30/2025  11:48 AM                depd
# d-----         1/30/2025  11:48 AM                destroy
# d-----         1/30/2025  11:49 AM                dotenv
# d-----         1/30/2025  11:48 AM                dunder-proto
# d-----         1/30/2025  11:49 AM                ecdsa-sig-formatter
# d-----         1/30/2025  11:48 AM                ee-first
# d-----         1/30/2025  11:48 AM                encodeurl
# d-----         1/30/2025  11:48 AM                es-define-property
# d-----         1/30/2025  11:48 AM                es-errors
# d-----         1/30/2025  11:48 AM                es-object-atoms
# d-----         3/23/2025   5:04 PM                es-set-tostringtag
# d-----         1/30/2025  11:48 AM                escape-html
# d-----         1/30/2025  11:48 AM                etag
# d-----         1/30/2025  11:48 AM                express
# d-----         1/30/2025  11:49 AM                fill-range
# d-----         1/30/2025  11:48 AM                finalhandler
# d-----         3/23/2025   5:04 PM                follow-redirects
# d-----         3/23/2025   5:04 PM                form-data
# d-----         1/30/2025  11:48 AM                forwarded
# d-----         1/30/2025  11:48 AM                fresh
# d-----         1/30/2025  11:48 AM                function-bind
# d-----         1/30/2025  11:48 AM                get-intrinsic
# d-----         1/30/2025  11:48 AM                get-proto
# d-----         1/30/2025  11:49 AM                glob-parent
# d-----         1/30/2025  11:48 AM                gopd
# d-----         1/30/2025  11:49 AM                has-flag
# d-----         1/30/2025  11:48 AM                has-symbols
# d-----         3/23/2025   5:04 PM                has-tostringtag
# d-----         1/30/2025  11:48 AM                hasown
# d-----         1/30/2025  11:48 AM                http-errors
# d-----          4/4/2025   1:36 PM                https-proxy-agent
# d-----         1/30/2025  11:48 AM                iconv-lite
# d-----         1/30/2025  11:49 AM                ignore-by-default
# d-----         1/30/2025  11:48 AM                inherits
# d-----         1/30/2025  11:48 AM                ipaddr.js
# d-----         1/30/2025  11:49 AM                is-binary-path
# d-----         1/30/2025  11:49 AM                is-extglob
# d-----         1/30/2025  11:49 AM                is-glob
# d-----         1/30/2025  11:49 AM                is-number
# d-----         2/10/2025  11:21 AM                isarray
# d-----         4/10/2025   5:41 PM                isexe
# d-----         1/30/2025  11:49 AM                jsonwebtoken
# d-----         1/30/2025  11:49 AM                jwa
# d-----         1/30/2025  11:49 AM                jws
# d-----         1/30/2025  11:49 AM                kareem
# d-----         2/10/2025  11:32 AM                lodash
# d-----         1/30/2025  11:49 AM                lodash.includes
# d-----         1/30/2025  11:49 AM                lodash.isboolean
# d-----         1/30/2025  11:49 AM                lodash.isinteger
# d-----         1/30/2025  11:49 AM                lodash.isnumber
# d-----         1/30/2025  11:49 AM                lodash.isplainobject
# d-----         1/30/2025  11:49 AM                lodash.isstring
# d-----         1/30/2025  11:49 AM                lodash.once
# d-----         1/30/2025  11:48 AM                math-intrinsics
# d-----         1/30/2025  11:48 AM                media-typer
# d-----         1/30/2025  11:49 AM                memory-pager
# d-----         1/30/2025  11:48 AM                merge-descriptors
# d-----         1/30/2025  11:48 AM                methods
# d-----         1/30/2025  11:48 AM                mime
# d-----         1/30/2025  11:48 AM                mime-db
# d-----         1/30/2025  11:48 AM                mime-types
# d-----         1/30/2025  11:49 AM                minimatch
# d-----         2/10/2025  11:21 AM                minimist
# d-----         2/10/2025  11:21 AM                mkdirp
# d-----         1/30/2025  11:49 AM                mongodb
# d-----         1/30/2025  11:49 AM                mongodb-connection-string-url
# d-----         1/30/2025  11:49 AM                mongoose
# d-----         3/25/2025   1:40 PM                morgan
# d-----         1/30/2025  11:49 AM                mpath
# d-----         1/30/2025  11:49 AM                mquery
# d-----         1/30/2025  11:48 AM                ms
# d-----         2/10/2025  11:21 AM                multer
# d-----         1/30/2025  11:48 AM                negotiator
# d-----         3/30/2025   6:03 PM                nodemailer
# d-----         1/30/2025  11:49 AM                nodemon
# d-----         1/30/2025  11:49 AM                normalize-path
# d-----         1/30/2025  11:49 AM                object-assign
# d-----         1/30/2025  11:48 AM                object-inspect
# d-----         1/30/2025  11:48 AM                on-finished
# d-----         3/25/2025   1:40 PM                on-headers
# d-----         1/30/2025  11:48 AM                parseurl
# d-----         4/10/2025   5:41 PM                path-key
# d-----         1/30/2025  11:48 AM                path-to-regexp
# d-----         1/30/2025  11:49 AM                picomatch
# d-----         2/10/2025  11:21 AM                process-nextick-args
# d-----         1/30/2025  11:48 AM                proxy-addr
# d-----         3/23/2025   5:04 PM                proxy-from-env
# d-----         1/30/2025  11:49 AM                pstree.remy
# d-----         1/30/2025  11:49 AM                punycode
# d-----         2/10/2025  11:32 AM                q
# d-----         1/30/2025  11:48 AM                qs
# d-----         1/30/2025  11:48 AM                range-parser
# d-----         1/30/2025  11:48 AM                raw-body
# d-----         2/10/2025  11:21 AM                readable-stream
# d-----         1/30/2025  11:49 AM                readdirp
# d-----         1/30/2025  11:48 AM                safe-buffer
# d-----         1/30/2025  11:48 AM                safer-buffer
# d-----          4/4/2025   1:36 PM                scmp
# d-----         1/30/2025  11:49 AM                semver
# d-----         1/30/2025  11:48 AM                send
# d-----         1/30/2025  11:48 AM                serve-static
# d-----         1/30/2025  11:48 AM                setprototypeof
# d-----         4/10/2025   5:41 PM                shebang-command
# d-----         4/10/2025   5:41 PM                shebang-regex
# d-----         1/30/2025  11:48 AM                side-channel
# d-----         1/30/2025  11:48 AM                side-channel-list
# d-----         1/30/2025  11:48 AM                side-channel-map
# d-----         1/30/2025  11:48 AM                side-channel-weakmap
# d-----         1/30/2025  11:49 AM                sift
# d-----         1/30/2025  11:49 AM                simple-update-notifier
# d-----         1/30/2025  11:49 AM                sparse-bitfield
# d-----         1/30/2025  11:48 AM                statuses
# d-----         2/10/2025  11:21 AM                streamsearch
# d-----         2/10/2025  11:21 AM                string_decoder
# d-----         3/13/2025   5:27 PM                stripe
# d-----         1/30/2025  11:49 AM                supports-color
# d-----         1/30/2025  11:49 AM                to-regex-range
# d-----         1/30/2025  11:48 AM                toidentifier
# d-----         1/30/2025  11:49 AM                touch
# d-----         1/30/2025  11:49 AM                tr46
# d-----          4/4/2025   1:36 PM                twilio
# d-----         1/30/2025  11:48 AM                type-is
# d-----         2/10/2025  11:21 AM                typedarray
# d-----         1/30/2025  11:49 AM                undefsafe
# d-----         3/13/2025   5:27 PM                undici-types
# d-----         1/30/2025  11:48 AM                unpipe
# d-----         2/10/2025  11:21 AM                util-deprecate
# d-----         1/30/2025  11:48 AM                utils-merge
# d-----         1/30/2025  11:48 AM                vary
# d-----         1/30/2025  11:49 AM                webidl-conversions
# d-----         1/30/2025  11:49 AM                whatwg-url
# d-----         4/10/2025   5:41 PM                which
# d-----          4/4/2025   1:36 PM                xmlbuilder
# d-----         2/10/2025  11:21 AM                xtend
# -a----         4/10/2025   9:36 PM          78713 .package-lock.json
#
#
# Directory: D:\lms\server\node_modules\.bin
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         4/10/2025   5:41 PM            409 cross-env
# -a----         4/10/2025   5:41 PM            421 cross-env-shell
# -a----         4/10/2025   5:41 PM            341 cross-env-shell.cmd
# -a----         4/10/2025   5:41 PM            869 cross-env-shell.ps1
# -a----         4/10/2025   5:41 PM            335 cross-env.cmd
# -a----         4/10/2025   5:41 PM            845 cross-env.ps1
# -a----         1/30/2025  11:48 AM            371 mime
# -a----         1/30/2025  11:48 AM            316 mime.cmd
# -a----         1/30/2025  11:48 AM            769 mime.ps1
# -a----         2/10/2025  11:21 AM            383 mkdirp
# -a----         2/10/2025  11:21 AM            322 mkdirp.cmd
# -a----         2/10/2025  11:21 AM            793 mkdirp.ps1
# -a----         4/10/2025   5:41 PM            389 node-which
# -a----         4/10/2025   5:41 PM            325 node-which.cmd
# -a----         4/10/2025   5:41 PM            805 node-which.ps1
# -a----         1/30/2025  11:49 AM            393 nodemon
# -a----         1/30/2025  11:49 AM            327 nodemon.cmd
# -a----         1/30/2025  11:49 AM            813 nodemon.ps1
# -a----         1/30/2025  11:49 AM            393 nodetouch
# -a----         1/30/2025  11:49 AM            327 nodetouch.cmd
# -a----         1/30/2025  11:49 AM            813 nodetouch.ps1
# -a----         1/30/2025  11:49 AM            389 semver
# -a----         1/30/2025  11:49 AM            325 semver.cmd
# -a----         1/30/2025  11:49 AM            805 semver.ps1
#
#
# Directory: D:\lms\server\node_modules\@mongodb-js
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                saslprep
#
#
# Directory: D:\lms\server\node_modules\@mongodb-js\saslprep
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                dist
# -a----         1/30/2025  11:49 AM           1060 LICENSE
# -a----         1/30/2025  11:49 AM           2672 package.json
# -a----         1/30/2025  11:49 AM            735 readme.md
#
#
# Directory: D:\lms\server\node_modules\@mongodb-js\saslprep\dist
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM             88 .esm-wrapper.mjs
# -a----         1/30/2025  11:49 AM            177 browser.d.ts
# -a----         1/30/2025  11:49 AM            161 browser.d.ts.map
# -a----         1/30/2025  11:49 AM            641 browser.js
# -a----         1/30/2025  11:49 AM            370 browser.js.map
# -a----         1/30/2025  11:49 AM            134 code-points-data-browser.d.ts
# -a----         1/30/2025  11:49 AM            192 code-points-data-browser.d.ts.map
# -a----         1/30/2025  11:49 AM         560013 code-points-data-browser.js
# -a----         1/30/2025  11:49 AM            240 code-points-data-browser.js.map
# -a----         1/30/2025  11:49 AM            134 code-points-data.d.ts
# -a----         1/30/2025  11:49 AM            138 code-points-data.d.ts.map
# -a----         1/30/2025  11:49 AM           2894 code-points-data.js
# -a----         1/30/2025  11:49 AM            222 code-points-data.js.map
# -a----         1/30/2025  11:49 AM            389 code-points-src.d.ts
# -a----         1/30/2025  11:49 AM            323 code-points-src.d.ts.map
# -a----         1/30/2025  11:49 AM          29006 code-points-src.js
# -a----         1/30/2025  11:49 AM          30475 code-points-src.js.map
# -a----         1/30/2025  11:49 AM             61 generate-code-points.d.ts
# -a----         1/30/2025  11:49 AM            134 generate-code-points.d.ts.map
# -a----         1/30/2025  11:49 AM           3642 generate-code-points.js
# -a----         1/30/2025  11:49 AM           2207 generate-code-points.js.map
# -a----         1/30/2025  11:49 AM            541 index.d.ts
# -a----         1/30/2025  11:49 AM            414 index.d.ts.map
# -a----         1/30/2025  11:49 AM           2997 index.js
# -a----         1/30/2025  11:49 AM           2888 index.js.map
# -a----         1/30/2025  11:49 AM            512 memory-code-points.d.ts
# -a----         1/30/2025  11:49 AM            215 memory-code-points.d.ts.map
# -a----         1/30/2025  11:49 AM           1209 memory-code-points.js
# -a----         1/30/2025  11:49 AM            819 memory-code-points.js.map
# -a----         1/30/2025  11:49 AM            294 node.d.ts
# -a----         1/30/2025  11:49 AM            244 node.d.ts.map
# -a----         1/30/2025  11:49 AM            651 node.js
# -a----         1/30/2025  11:49 AM            397 node.js.map
# -a----         1/30/2025  11:49 AM            101 util.d.ts
# -a----         1/30/2025  11:49 AM            179 util.d.ts.map
# -a----         1/30/2025  11:49 AM            326 util.js
# -a----         1/30/2025  11:49 AM            393 util.js.map
#
#
# Directory: D:\lms\server\node_modules\@types
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/13/2025   5:27 PM                node
# d-----         1/30/2025  11:49 AM                webidl-conversions
# d-----         1/30/2025  11:49 AM                whatwg-url
#
#
# Directory: D:\lms\server\node_modules\@types\node
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/13/2025   5:27 PM                assert
# d-----         3/13/2025   5:27 PM                compatibility
# d-----         3/13/2025   5:27 PM                dns
# d-----         3/13/2025   5:27 PM                fs
# d-----         3/13/2025   5:27 PM                readline
# d-----         3/13/2025   5:27 PM                stream
# d-----         3/13/2025   5:27 PM                timers
# d-----         3/13/2025   5:27 PM                ts5.6
# -a----         3/13/2025   5:27 PM          46299 assert.d.ts
# -a----         3/13/2025   5:27 PM          23285 async_hooks.d.ts
# -a----         3/13/2025   5:27 PM          22197 buffer.buffer.d.ts
# -a----         3/13/2025   5:27 PM          87813 buffer.d.ts
# -a----         3/13/2025   5:27 PM          69757 child_process.d.ts
# -a----         3/13/2025   5:27 PM          28016 cluster.d.ts
# -a----         3/13/2025   5:27 PM          21249 console.d.ts
# -a----         3/13/2025   5:27 PM            816 constants.d.ts
# -a----         3/13/2025   5:27 PM         189956 crypto.d.ts
# -a----         3/13/2025   5:27 PM          27991 dgram.d.ts
# -a----         3/13/2025   5:27 PM          24043 diagnostics_channel.d.ts
# -a----         3/13/2025   5:27 PM          35538 dns.d.ts
# -a----         3/13/2025   5:27 PM           5871 dom-events.d.ts
# -a----         3/13/2025   5:27 PM           7812 domain.d.ts
# -a----         3/13/2025   5:27 PM          43169 events.d.ts
# -a----         3/13/2025   5:27 PM         185199 fs.d.ts
# -a----         3/13/2025   5:27 PM          19123 globals.d.ts
# -a----         3/13/2025   5:27 PM            777 globals.typedarray.d.ts
# -a----         3/13/2025   5:27 PM          87270 http.d.ts
# -a----         3/13/2025   5:27 PM         125692 http2.d.ts
# -a----         3/13/2025   5:27 PM          24727 https.d.ts
# -a----         3/13/2025   5:27 PM           3868 index.d.ts
# -a----         3/13/2025   5:27 PM         197531 inspector.d.ts
# -a----         3/13/2025   5:27 PM           1141 LICENSE
# -a----         3/13/2025   5:27 PM          32093 module.d.ts
# -a----         3/13/2025   5:27 PM          47540 net.d.ts
# -a----         3/13/2025   5:27 PM          18956 os.d.ts
# -a----         3/13/2025   5:27 PM           6526 package.json
# -a----         3/13/2025   5:27 PM           8235 path.d.ts
# -a----         3/13/2025   5:27 PM          38574 perf_hooks.d.ts
# -a----         3/13/2025   5:27 PM         102454 process.d.ts
# -a----         3/13/2025   5:27 PM           5479 punycode.d.ts
# -a----         3/13/2025   5:27 PM           7137 querystring.d.ts
# -a----         3/13/2025   5:27 PM          25736 readline.d.ts
# -a----         3/13/2025   5:27 PM           2243 README.md
# -a----         3/13/2025   5:27 PM          19507 repl.d.ts
# -a----         3/13/2025   5:27 PM           6195 sea.d.ts
# -a----         3/13/2025   5:27 PM          21606 sqlite.d.ts
# -a----         3/13/2025   5:27 PM          84925 stream.d.ts
# -a----         3/13/2025   5:27 PM           2827 string_decoder.d.ts
# -a----         3/13/2025   5:27 PM          87491 test.d.ts
# -a----         3/13/2025   5:27 PM          12272 timers.d.ts
# -a----         3/13/2025   5:27 PM          57565 tls.d.ts
# -a----         3/13/2025   5:27 PM           8926 trace_events.d.ts
# -a----         3/13/2025   5:27 PM          10053 tty.d.ts
# -a----         3/13/2025   5:27 PM          42696 url.d.ts
# -a----         3/13/2025   5:27 PM          94074 util.d.ts
# -a----         3/13/2025   5:27 PM          34772 v8.d.ts
# -a----         3/13/2025   5:27 PM          43724 vm.d.ts
# -a----         3/13/2025   5:27 PM           7935 wasi.d.ts
# -a----         3/13/2025   5:27 PM          36430 worker_threads.d.ts
# -a----         3/13/2025   5:27 PM          20640 zlib.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\assert
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM            201 strict.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\compatibility
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM            473 disposable.d.ts
# -a----         3/13/2025   5:27 PM            533 index.d.ts
# -a----         3/13/2025   5:27 PM           1195 indexable.d.ts
# -a----         3/13/2025   5:27 PM           1303 iterators.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\dns
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM          20582 promises.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\fs
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM          55651 promises.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\readline
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM           6444 promises.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\stream
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM            727 consumers.d.ts
# -a----         3/13/2025   5:27 PM           2971 promises.d.ts
# -a----         3/13/2025   5:27 PM          29584 web.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\timers
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM           3497 promises.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\node\ts5.6
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM          21560 buffer.buffer.d.ts
# -a----         3/13/2025   5:27 PM            457 globals.typedarray.d.ts
# -a----         3/13/2025   5:27 PM           4062 index.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\webidl-conversions
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM           4076 index.d.ts
# -a----         1/30/2025  11:49 AM           1141 LICENSE
# -a----         1/30/2025  11:49 AM            985 package.json
# -a----         1/30/2025  11:49 AM            565 README.md
#
#
# Directory: D:\lms\server\node_modules\@types\whatwg-url
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                lib
# -a----         1/30/2025  11:49 AM           4892 index.d.ts
# -a----         1/30/2025  11:49 AM           1141 LICENSE
# -a----         1/30/2025  11:49 AM           1149 package.json
# -a----         1/30/2025  11:49 AM            656 README.md
# -a----         1/30/2025  11:49 AM            126 webidl2js-wrapper.d.ts
#
#
# Directory: D:\lms\server\node_modules\@types\whatwg-url\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM            590 URL-impl.d.ts
# -a----         1/30/2025  11:49 AM           2240 URL.d.ts
# -a----         1/30/2025  11:49 AM            706 URLSearchParams-impl.d.ts
# -a----         1/30/2025  11:49 AM           3357 URLSearchParams.d.ts
#
#
# Directory: D:\lms\server\node_modules\accepts
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:48 AM           5096 HISTORY.md
# -a----         1/30/2025  11:48 AM           5252 index.js
# -a----         1/30/2025  11:48 AM           1167 LICENSE
# -a----         1/30/2025  11:48 AM           1157 package.json
# -a----         1/30/2025  11:48 AM           4123 README.md
#
#
# Directory: D:\lms\server\node_modules\agent-base
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----          4/4/2025   1:36 PM                dist
# d-----          4/4/2025   1:36 PM                node_modules
# d-----          4/4/2025   1:36 PM                src
# -a----          4/4/2025   1:36 PM           1635 package.json
# -a----          4/4/2025   1:36 PM           5056 README.md
#
#
# Directory: D:\lms\server\node_modules\agent-base\dist
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----          4/4/2025   1:36 PM                src
#
#
# Directory: D:\lms\server\node_modules\agent-base\dist\src
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM           3197 index.d.ts
# -a----          4/4/2025   1:36 PM           7910 index.js
# -a----          4/4/2025   1:36 PM           5824 index.js.map
# -a----          4/4/2025   1:36 PM            299 promisify.d.ts
# -a----          4/4/2025   1:36 PM            495 promisify.js
# -a----          4/4/2025   1:36 PM            499 promisify.js.map
#
#
# Directory: D:\lms\server\node_modules\agent-base\node_modules
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----          4/4/2025   1:36 PM                debug
# d-----          4/4/2025   1:36 PM                ms
#
#
# Directory: D:\lms\server\node_modules\agent-base\node_modules\debug
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----          4/4/2025   1:36 PM                src
# -a----          4/4/2025   1:36 PM           1139 LICENSE
# -a----          4/4/2025   1:36 PM           1524 package.json
# -a----          4/4/2025   1:36 PM          22115 README.md
#
#
# Directory: D:\lms\server\node_modules\agent-base\node_modules\debug\src
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM           6066 browser.js
# -a----          4/4/2025   1:36 PM           6912 common.js
# -a----          4/4/2025   1:36 PM            314 index.js
# -a----          4/4/2025   1:36 PM           4728 node.js
#
#
# Directory: D:\lms\server\node_modules\agent-base\node_modules\ms
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM           3024 index.js
# -a----          4/4/2025   1:36 PM           1079 license.md
# -a----          4/4/2025   1:36 PM            732 package.json
# -a----          4/4/2025   1:36 PM           1886 readme.md
#
#
# Directory: D:\lms\server\node_modules\agent-base\src
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM           9018 index.ts
# -a----          4/4/2025   1:36 PM            649 promisify.ts
#
#
# Directory: D:\lms\server\node_modules\anymatch
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM            763 index.d.ts
# -a----         1/30/2025  11:49 AM           3180 index.js
# -a----         1/30/2025  11:49 AM            784 LICENSE
# -a----         1/30/2025  11:49 AM            904 package.json
# -a----         1/30/2025  11:49 AM           4023 README.md
#
#
# Directory: D:\lms\server\node_modules\append-field
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         2/10/2025  11:21 AM                lib
# d-----         2/10/2025  11:21 AM                test
# -a----         2/10/2025  11:21 AM             14 .npmignore
# -a----         2/10/2025  11:21 AM            307 index.js
# -a----         2/10/2025  11:21 AM           1082 LICENSE
# -a----         2/10/2025  11:21 AM            416 package.json
# -a----         2/10/2025  11:21 AM           1016 README.md
#
#
# Directory: D:\lms\server\node_modules\append-field\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025  11:21 AM           1112 parse-path.js
# -a----         2/10/2025  11:21 AM           1642 set-value.js
#
#
# Directory: D:\lms\server\node_modules\append-field\test
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025  11:21 AM            450 forms.js
#
#
# Directory: D:\lms\server\node_modules\array-flatten
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:48 AM           1195 array-flatten.js
# -a----         1/30/2025  11:48 AM           1103 LICENSE
# -a----         1/30/2025  11:48 AM            879 package.json
# -a----         1/30/2025  11:48 AM           1245 README.md
#
#
# Directory: D:\lms\server\node_modules\asynckit
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                lib
# -a----         3/23/2025   5:04 PM           1256 bench.js
# -a----         3/23/2025   5:04 PM            156 index.js
# -a----         3/23/2025   5:04 PM           1078 LICENSE
# -a----         3/23/2025   5:04 PM           1611 package.json
# -a----         3/23/2025   5:04 PM           1017 parallel.js
# -a----         3/23/2025   5:04 PM           7640 README.md
# -a----         3/23/2025   5:04 PM            501 serial.js
# -a----         3/23/2025   5:04 PM           1751 serialOrdered.js
# -a----         3/23/2025   5:04 PM            703 stream.js
#
#
# Directory: D:\lms\server\node_modules\asynckit\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM            497 abort.js
# -a----         3/23/2025   5:04 PM            599 async.js
# -a----         3/23/2025   5:04 PM            441 defer.js
# -a----         3/23/2025   5:04 PM           1794 iterate.js
# -a----         3/23/2025   5:04 PM           1611 readable_asynckit.js
# -a----         3/23/2025   5:04 PM            673 readable_parallel.js
# -a----         3/23/2025   5:04 PM            655 readable_serial.js
# -a----         3/23/2025   5:04 PM            941 readable_serial_ordered.js
# -a----         3/23/2025   5:04 PM            941 state.js
# -a----         3/23/2025   5:04 PM           2964 streamify.js
# -a----         3/23/2025   5:04 PM            533 terminator.js
#
#
# Directory: D:\lms\server\node_modules\axios
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                dist
# d-----         3/23/2025   5:04 PM                lib
# -a----         3/23/2025   5:04 PM          77056 CHANGELOG.md
# -a----         3/23/2025   5:04 PM          18401 index.d.cts
# -a----         3/23/2025   5:04 PM          18471 index.d.ts
# -a----         3/23/2025   5:04 PM            681 index.js
# -a----         3/23/2025   5:04 PM           1084 LICENSE
# -a----         3/23/2025   5:04 PM             37 MIGRATION_GUIDE.md
# -a----         3/23/2025   5:04 PM           7671 package.json
# -a----         3/23/2025   5:04 PM          65077 README.md
#
#
# Directory: D:\lms\server\node_modules\axios\dist
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                browser
# d-----         3/23/2025   5:04 PM                esm
# d-----         3/23/2025   5:04 PM                node
# -a----         3/23/2025   5:04 PM         144333 axios.js
# -a----         3/23/2025   5:04 PM         240754 axios.js.map
# -a----         3/23/2025   5:04 PM          53988 axios.min.js
# -a----         3/23/2025   5:04 PM         170708 axios.min.js.map
#
#
# Directory: D:\lms\server\node_modules\axios\dist\browser
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM          96565 axios.cjs
# -a----         3/23/2025   5:04 PM         206335 axios.cjs.map
#
#
# Directory: D:\lms\server\node_modules\axios\dist\esm
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM          97441 axios.js
# -a----         3/23/2025   5:04 PM         207611 axios.js.map
# -a----         3/23/2025   5:04 PM          35202 axios.min.js
# -a----         3/23/2025   5:04 PM         162074 axios.min.js.map
#
#
# Directory: D:\lms\server\node_modules\axios\dist\node
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM         128909 axios.cjs
# -a----         3/23/2025   5:04 PM         272624 axios.cjs.map
#
#
# Directory: D:\lms\server\node_modules\axios\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                adapters
# d-----         3/23/2025   5:04 PM                cancel
# d-----         3/23/2025   5:04 PM                core
# d-----         3/23/2025   5:04 PM                defaults
# d-----         3/23/2025   5:04 PM                env
# d-----         3/23/2025   5:04 PM                helpers
# d-----         3/23/2025   5:04 PM                platform
# -a----         3/23/2025   5:04 PM           2549 axios.js
# -a----         3/23/2025   5:04 PM          18265 utils.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\adapters
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM           1970 adapters.js
# -a----         3/23/2025   5:04 PM           6637 fetch.js
# -a----         3/23/2025   5:04 PM          22550 http.js
# -a----         3/23/2025   5:04 PM            915 README.md
# -a----         3/23/2025   5:04 PM           6623 xhr.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\cancel
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM            697 CanceledError.js
# -a----         3/23/2025   5:04 PM           2789 CancelToken.js
# -a----         3/23/2025   5:04 PM             99 isCancel.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\core
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM           6862 Axios.js
# -a----         3/23/2025   5:04 PM           2546 AxiosError.js
# -a----         3/23/2025   5:04 PM           7032 AxiosHeaders.js
# -a----         3/23/2025   5:04 PM            783 buildFullPath.js
# -a----         3/23/2025   5:04 PM           2187 dispatchRequest.js
# -a----         3/23/2025   5:04 PM           1569 InterceptorManager.js
# -a----         3/23/2025   5:04 PM           3415 mergeConfig.js
# -a----         3/23/2025   5:04 PM            399 README.md
# -a----         3/23/2025   5:04 PM            836 settle.js
# -a----         3/23/2025   5:04 PM            778 transformData.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\defaults
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM           4479 index.js
# -a----         3/23/2025   5:04 PM            118 transitional.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\env
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                classes
# -a----         3/23/2025   5:04 PM             31 data.js
# -a----         3/23/2025   5:04 PM            131 README.md
#
#
# Directory: D:\lms\server\node_modules\axios\lib\env\classes
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM            106 FormData.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\helpers
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM           3680 AxiosTransformStream.js
# -a----         3/23/2025   5:04 PM           1439 AxiosURLSearchParams.js
# -a----         3/23/2025   5:04 PM            134 bind.js
# -a----         3/23/2025   5:04 PM           1659 buildURL.js
# -a----         3/23/2025   5:04 PM            372 callbackify.js
# -a----         3/23/2025   5:04 PM            382 combineURLs.js
# -a----         3/23/2025   5:04 PM           1364 composeSignals.js
# -a----         3/23/2025   5:04 PM           1045 cookies.js
# -a----         3/23/2025   5:04 PM            746 deprecatedMethod.js
# -a----         3/23/2025   5:04 PM           2164 formDataToJSON.js
# -a----         3/23/2025   5:04 PM           2972 formDataToStream.js
# -a----         3/23/2025   5:04 PM           1365 fromDataURI.js
# -a----         3/23/2025   5:04 PM           1600 HttpStatusCode.js
# -a----         3/23/2025   5:04 PM            561 isAbsoluteURL.js
# -a----         3/23/2025   5:04 PM            373 isAxiosError.js
# -a----         3/23/2025   5:04 PM            420 isURLSameOrigin.js
# -a----         3/23/2025   5:04 PM             56 null.js
# -a----         3/23/2025   5:04 PM           1382 parseHeaders.js
# -a----         3/23/2025   5:04 PM            151 parseProtocol.js
# -a----         3/23/2025   5:04 PM           1235 progressEventReducer.js
# -a----         3/23/2025   5:04 PM            318 readBlob.js
# -a----         3/23/2025   5:04 PM            351 README.md
# -a----         3/23/2025   5:04 PM           2125 resolveConfig.js
# -a----         3/23/2025   5:04 PM           1092 speedometer.js
# -a----         3/23/2025   5:04 PM            564 spread.js
# -a----         3/23/2025   5:04 PM            861 throttle.js
# -a----         3/23/2025   5:04 PM           6044 toFormData.js
# -a----         3/23/2025   5:04 PM            548 toURLEncodedForm.js
# -a----         3/23/2025   5:04 PM           1686 trackStream.js
# -a----         3/23/2025   5:04 PM           2785 validator.js
# -a----         3/23/2025   5:04 PM            681 ZlibHeaderTransformStream.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                browser
# d-----         3/23/2025   5:04 PM                common
# d-----         3/23/2025   5:04 PM                node
# -a----         3/23/2025   5:04 PM            130 index.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform\browser
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                classes
# -a----         3/23/2025   5:04 PM            305 index.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform\browser\classes
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM             71 Blob.js
# -a----         3/23/2025   5:04 PM             81 FormData.js
# -a----         3/23/2025   5:04 PM            188 URLSearchParams.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform\common
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM           1595 utils.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform\node
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/23/2025   5:04 PM                classes
# -a----         3/23/2025   5:04 PM            828 index.js
#
#
# Directory: D:\lms\server\node_modules\axios\lib\platform\node\classes
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/23/2025   5:04 PM             60 FormData.js
# -a----         3/23/2025   5:04 PM             74 URLSearchParams.js
#
#
# Directory: D:\lms\server\node_modules\balanced-match
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                .github
# -a----         1/30/2025  11:49 AM           1219 index.js
# -a----         1/30/2025  11:49 AM           1096 LICENSE.md
# -a----         1/30/2025  11:49 AM           1069 package.json
# -a----         1/30/2025  11:49 AM           3502 README.md
#
#
# Directory: D:\lms\server\node_modules\balanced-match\.github
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM             53 FUNDING.yml
#
#
# Directory: D:\lms\server\node_modules\basic-auth
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/25/2025   1:40 PM                node_modules
# -a----         3/25/2025   1:40 PM           1052 HISTORY.md
# -a----         3/25/2025   1:40 PM           2361 index.js
# -a----         3/25/2025   1:40 PM           1206 LICENSE
# -a----         3/25/2025   1:40 PM           1084 package.json
# -a----         3/25/2025   1:40 PM           3192 README.md
#
#
# Directory: D:\lms\server\node_modules\basic-auth\node_modules
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/25/2025   1:40 PM                safe-buffer
#
#
# Directory: D:\lms\server\node_modules\basic-auth\node_modules\safe-buffer
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/25/2025   1:40 PM           8738 index.d.ts
# -a----         3/25/2025   1:40 PM           1529 index.js
# -a----         3/25/2025   1:40 PM           1081 LICENSE
# -a----         3/25/2025   1:40 PM            783 package.json
# -a----         3/25/2025   1:40 PM          19555 README.md
#
#
# Directory: D:\lms\server\node_modules\bcryptjs
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                .vscode
# d-----         1/30/2025  11:49 AM                bin
# d-----         1/30/2025  11:49 AM                dist
# d-----         1/30/2025  11:49 AM                externs
# d-----         1/30/2025  11:49 AM                scripts
# d-----         1/30/2025  11:49 AM                src
# d-----         1/30/2025  11:49 AM                tests
# -a----         1/30/2025  11:49 AM             71 .npmignore
# -a----         1/30/2025  11:49 AM            226 .travis.yml
# -a----         1/30/2025  11:49 AM            632 bower.json
# -a----         1/30/2025  11:49 AM           1604 index.js
# -a----         1/30/2025  11:49 AM           2665 LICENSE
# -a----         1/30/2025  11:49 AM           1522 package.json
# -a----         1/30/2025  11:49 AM          10149 README.md
#
#
# Directory: D:\lms\server\node_modules\bcryptjs\.vscode
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM             42 settings.json
#
#
# Directory: D:\lms\server\node_modules\bcryptjs\bin
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM            877 bcrypt
#
#
# Directory: D:\lms\server\node_modules\bcryptjs\dist
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM          56908 bcrypt.js
# -a----         1/30/2025  11:49 AM          21634 bcrypt.min.js
# -a----         1/30/2025  11:49 AM           9443 bcrypt.min.js.gz
# -a----         1/30/2025  11:49 AM          42466 bcrypt.min.map
# -a----         1/30/2025  11:49 AM            677 README.md
#
#
# Directory: D:\lms\server\node_modules\bcryptjs\externs
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM           2178 bcrypt.js
# -a----         1/30/2025  11:49 AM           1480 minimal-env.js
#
#
# Directory: D:\lms\server\node_modules\bcryptjs\scripts
#
#
# Mode                 LastWriteTime         Length Name
# ...
# -a----         2/10/2025  11:21 AM            217 tarray.js
#
#
# Directory: D:\lms\server\node_modules\typedarray\test\server
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025  11:21 AM            468 undef_globals.js
#
#
# Directory: D:\lms\server\node_modules\undefsafe
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                .github
# d-----         1/30/2025  11:49 AM                lib
# -a----         1/30/2025  11:49 AM            364 .jscsrc
# -a----         1/30/2025  11:49 AM            240 .jshintrc
# -a----         1/30/2025  11:49 AM            283 .travis.yml
# -a----         1/30/2025  11:49 AM            245 example.js
# -a----         1/30/2025  11:49 AM           1119 LICENSE
# -a----         1/30/2025  11:49 AM            784 package.json
# -a----         1/30/2025  11:49 AM           1414 README.md
#
#
# Directory: D:\lms\server\node_modules\undefsafe\.github
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                workflows
#
#
# Directory: D:\lms\server\node_modules\undefsafe\.github\workflows
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM            556 release.yml
#
#
# Directory: D:\lms\server\node_modules\undefsafe\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM           2595 undefsafe.js
#
#
# Directory: D:\lms\server\node_modules\undici-types
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/13/2025   5:27 PM           1065 agent.d.ts
# -a----         3/13/2025   5:27 PM           1455 api.d.ts
# -a----         3/13/2025   5:27 PM            961 balanced-pool.d.ts
# -a----         3/13/2025   5:27 PM           1251 cache.d.ts
# -a----         3/13/2025   5:27 PM           4964 client.d.ts
# -a----         3/13/2025   5:27 PM           1029 connector.d.ts
# -a----         3/13/2025   5:27 PM            561 content-type.d.ts
# -a----         3/13/2025   5:27 PM            635 cookies.d.ts
# -a----         3/13/2025   5:27 PM           1579 diagnostics-channel.d.ts
# -a----         3/13/2025   5:27 PM          14188 dispatcher.d.ts
# -a----         3/13/2025   5:27 PM            675 env-http-proxy-agent.d.ts
# -a----         3/13/2025   5:27 PM           4280 errors.d.ts
# -a----         3/13/2025   5:27 PM           1648 eventsource.d.ts
# -a----         3/13/2025   5:27 PM           5575 fetch.d.ts
# -a----         3/13/2025   5:27 PM           1707 file.d.ts
# -a----         3/13/2025   5:27 PM           1433 filereader.d.ts
# -a----         3/13/2025   5:27 PM           4998 formdata.d.ts
# -a----         3/13/2025   5:27 PM            276 global-dispatcher.d.ts
# -a----         3/13/2025   5:27 PM            175 global-origin.d.ts
# -a----         3/13/2025   5:27 PM            447 handlers.d.ts
# -a----         3/13/2025   5:27 PM            133 header.d.ts
# -a----         3/13/2025   5:27 PM           3387 index.d.ts
# -a----         3/13/2025   5:27 PM            922 interceptors.d.ts
# -a----         3/13/2025   5:27 PM           1090 LICENSE
# -a----         3/13/2025   5:27 PM           2535 mock-agent.d.ts
# -a----         3/13/2025   5:27 PM           1002 mock-client.d.ts
# -a----         3/13/2025   5:27 PM            338 mock-errors.d.ts
# -a----         3/13/2025   5:27 PM           3902 mock-interceptor.d.ts
# -a----         3/13/2025   5:27 PM            974 mock-pool.d.ts
# -a----         3/13/2025   5:27 PM           1193 package.json
# -a----         3/13/2025   5:27 PM            691 patch.d.ts
# -a----         3/13/2025   5:27 PM            669 pool-stats.d.ts
# -a----         3/13/2025   5:27 PM           1336 pool.d.ts
# -a----         3/13/2025   5:27 PM            780 proxy-agent.d.ts
# -a----         3/13/2025   5:27 PM           1595 readable.d.ts
# -a----         3/13/2025   5:27 PM            455 README.md
# -a----         3/13/2025   5:27 PM            232 retry-agent.d.ts
# -a----         3/13/2025   5:27 PM           2983 retry-handler.d.ts
# -a----         3/13/2025   5:27 PM            623 util.d.ts
# -a----         3/13/2025   5:27 PM           5767 webidl.d.ts
# -a----         3/13/2025   5:27 PM           3840 websocket.d.ts
#
#
# Directory: D:\lms\server\node_modules\unpipe
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:48 AM             59 HISTORY.md
# -a----         1/30/2025  11:48 AM           1118 index.js
# -a----         1/30/2025  11:48 AM           1114 LICENSE
# -a----         1/30/2025  11:48 AM            770 package.json
# -a----         1/30/2025  11:48 AM           1250 README.md
#
#
# Directory: D:\lms\server\node_modules\util-deprecate
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025  11:21 AM           1614 browser.js
# -a----         2/10/2025  11:21 AM            282 History.md
# -a----         2/10/2025  11:21 AM           1102 LICENSE
# -a----         2/10/2025  11:21 AM            123 node.js
# -a----         2/10/2025  11:21 AM            694 package.json
# -a----         2/10/2025  11:21 AM           1666 README.md
#
#
# Directory: D:\lms\server\node_modules\utils-merge
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:48 AM             79 .npmignore
# -a----         1/30/2025  11:48 AM            381 index.js
# -a----         1/30/2025  11:48 AM           1084 LICENSE
# -a----         1/30/2025  11:48 AM            857 package.json
# -a----         1/30/2025  11:48 AM           1319 README.md
#
#
# Directory: D:\lms\server\node_modules\vary
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:48 AM            792 HISTORY.md
# -a----         1/30/2025  11:48 AM           2930 index.js
# -a----         1/30/2025  11:48 AM           1094 LICENSE
# -a----         1/30/2025  11:48 AM           1215 package.json
# -a----         1/30/2025  11:48 AM           2716 README.md
#
#
# Directory: D:\lms\server\node_modules\webidl-conversions
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                lib
# -a----         1/30/2025  11:49 AM           1323 LICENSE.md
# -a----         1/30/2025  11:49 AM            982 package.json
# -a----         1/30/2025  11:49 AM           9212 README.md
#
#
# Directory: D:\lms\server\node_modules\webidl-conversions\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM          12725 index.js
#
#
# Directory: D:\lms\server\node_modules\whatwg-url
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         1/30/2025  11:49 AM                lib
# -a----         1/30/2025  11:49 AM           1264 index.js
# -a----         1/30/2025  11:49 AM           1076 LICENSE.txt
# -a----         1/30/2025  11:49 AM           1315 package.json
# -a----         1/30/2025  11:49 AM           7074 README.md
# -a----         1/30/2025  11:49 AM            170 webidl2js-wrapper.js
#
#
# Directory: D:\lms\server\node_modules\whatwg-url\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         1/30/2025  11:49 AM            328 encoding.js
# -a----         1/30/2025  11:49 AM           1186 Function.js
# -a----         1/30/2025  11:49 AM            518 infra.js
# -a----         1/30/2025  11:49 AM           4887 percent-encoding.js
# -a----         1/30/2025  11:49 AM           5509 URL-impl.js
# -a----         1/30/2025  11:49 AM          31103 url-state-machine.js
# -a----         1/30/2025  11:49 AM          15382 URL.js
# -a----         1/30/2025  11:49 AM           2760 urlencoded.js
# -a----         1/30/2025  11:49 AM           3086 URLSearchParams-impl.js
# -a----         1/30/2025  11:49 AM          17119 URLSearchParams.js
# -a----         1/30/2025  11:49 AM           5390 utils.js
# -a----         1/30/2025  11:49 AM            728 VoidFunction.js
#
#
# Directory: D:\lms\server\node_modules\which
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         4/10/2025   5:41 PM                bin
# -a----         4/10/2025   5:41 PM           2667 CHANGELOG.md
# -a----         4/10/2025   5:41 PM            765 LICENSE
# -a----         4/10/2025   5:41 PM           1043 package.json
# -a----         4/10/2025   5:41 PM           1352 README.md
# -a----         4/10/2025   5:41 PM           3163 which.js
#
#
# Directory: D:\lms\server\node_modules\which\bin
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         4/10/2025   5:41 PM            985 node-which
#
#
# Directory: D:\lms\server\node_modules\xmlbuilder
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----          4/4/2025   1:36 PM                lib
# d-----          4/4/2025   1:36 PM                typings
# -a----          4/4/2025   1:36 PM            120 .nycrc
# -a----          4/4/2025   1:36 PM          25483 CHANGELOG.md
# -a----          4/4/2025   1:36 PM           1101 LICENSE
# -a----          4/4/2025   1:36 PM            898 package.json
# -a----          4/4/2025   1:36 PM           2732 README.md
#
#
# Directory: D:\lms\server\node_modules\xmlbuilder\lib
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM            155 Derivation.js
# -a----          4/4/2025   1:36 PM            217 DocumentPosition.js
# -a----          4/4/2025   1:36 PM           4500 index.js
# -a----          4/4/2025   1:36 PM            577 NodeType.js
# -a----          4/4/2025   1:36 PM            170 OperationType.js
# -a----          4/4/2025   1:36 PM           2390 Utility.js
# -a----          4/4/2025   1:36 PM            154 WriterState.js
# -a----          4/4/2025   1:36 PM           3321 XMLAttribute.js
# -a----          4/4/2025   1:36 PM           1175 XMLCData.js
# -a----          4/4/2025   1:36 PM           2081 XMLCharacterData.js
# -a----          4/4/2025   1:36 PM           1188 XMLComment.js
# -a----          4/4/2025   1:36 PM           1593 XMLDeclaration.js
# -a----          4/4/2025   1:36 PM           6944 XMLDocType.js
# -a----          4/4/2025   1:36 PM           9070 XMLDocument.js
# -a----          4/4/2025   1:36 PM          20683 XMLDocumentCB.js
# -a----          4/4/2025   1:36 PM            495 XMLDocumentFragment.js
# -a----          4/4/2025   1:36 PM           2243 XMLDOMConfiguration.js
# -a----          4/4/2025   1:36 PM            463 XMLDOMErrorHandler.js
# -a----          4/4/2025   1:36 PM           1980 XMLDOMImplementation.js
# -a----          4/4/2025   1:36 PM           1029 XMLDOMStringList.js
# -a----          4/4/2025   1:36 PM           2737 XMLDTDAttList.js
# -a----          4/4/2025   1:36 PM           1351 XMLDTDElement.js
# -a----          4/4/2025   1:36 PM           3627 XMLDTDEntity.js
# -a----          4/4/2025   1:36 PM           2049 XMLDTDNotation.js
# -a----          4/4/2025   1:36 PM           1097 XMLDummy.js
# -a----          4/4/2025   1:36 PM           9862 XMLElement.js
# -a----          4/4/2025   1:36 PM           1961 XMLNamedNodeMap.js
# -a----          4/4/2025   1:36 PM          31019 XMLNode.js
# -a----          4/4/2025   1:36 PM           1216 XMLNodeFilter.js
# -a----          4/4/2025   1:36 PM           1057 XMLNodeList.js
# -a----          4/4/2025   1:36 PM           1647 XMLProcessingInstruction.js
# -a----          4/4/2025   1:36 PM           1083 XMLRaw.js
# -a----          4/4/2025   1:36 PM           7468 XMLStreamWriter.js
# -a----          4/4/2025   1:36 PM           9034 XMLStringifier.js
# -a----          4/4/2025   1:36 PM           1320 XMLStringWriter.js
# -a----          4/4/2025   1:36 PM           2310 XMLText.js
# -a----          4/4/2025   1:36 PM            630 XMLTypeInfo.js
# -a----          4/4/2025   1:36 PM            945 XMLUserDataHandler.js
# -a----          4/4/2025   1:36 PM          16996 XMLWriterBase.js
#
#
# Directory: D:\lms\server\node_modules\xmlbuilder\typings
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:36 PM          53337 index.d.ts
#
#
# Directory: D:\lms\server\node_modules\xtend
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025  11:21 AM            545 .jshintrc
# -a----         2/10/2025  11:21 AM            384 immutable.js
# -a----         2/10/2025  11:21 AM           1078 LICENSE
# -a----         2/10/2025  11:21 AM            369 mutable.js
# -a----         2/10/2025  11:21 AM           1056 package.json
# -a----         2/10/2025  11:21 AM            726 README.md
# -a----         2/10/2025  11:21 AM           2307 test.js
#
#
# Directory: D:\lms\server\routes
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         3/30/2025  12:03 PM            728 batch.route.js
# -a----          4/3/2025  11:47 PM           1443 course.route.js
# -a----         3/17/2025   1:25 PM            650 courseProgress.route.js
# -a----         3/26/2025   4:33 PM            467 instructor.routes.js
# -a----         2/27/2025   1:08 PM            597 media.route.js
# -a----         3/16/2025   2:42 PM            727 purchaseCourse.route.js
# -a----          4/4/2025   2:42 PM            724 student.routes.js
# -a----          4/7/2025   1:23 PM           1043 user.route.js
# -a----         3/24/2025   5:19 PM           1714 zoom.route.js
#
#
# Directory: D:\lms\server\uploads
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----          4/4/2025   1:22 AM         760087 04a790affaa2fd29c2fdddc0f665901a
# -a----          4/4/2025   1:23 AM       10194239 0ef9d318b586742223182391776fb102
# -a----          4/9/2025   1:00 PM         291813 0f9741b02e7343bd766fcfa7fa4ec24c
# -a----         4/10/2025   5:30 PM          42192 0fed0ca5d9f8a1acc0c7029871e53897
# -a----          4/3/2025   7:05 PM         127295 3e8618729dee9c2dbf5f91b31cd6e4eb
# -a----          4/4/2025  12:25 AM         760087 6f92c63fb87c94c4841d727473932a78
# -a----          4/3/2025   3:40 PM        1748109 a280e5050381e64d6579fabd0e38a2b0
# -a----          4/3/2025   9:38 PM         131060 b2bec60bcf13f250c13194a0f517a300
# -a----          4/3/2025   7:09 PM         140663 ca03de2e65647eeee76fb45cab03bc48
# -a----          4/3/2025  11:17 PM         131060 d21f02b9e4a9d428f9e09c26c2b50171
# -a----          4/2/2025   2:02 PM         126386 d255895225fc1b1572d282264d0381c6
# -a----          4/3/2025  10:09 PM         131060 d6da3234434a56768a3c0a22e26e009e
# -a----          4/3/2025   9:36 PM         760087 e85bcc59f7c0a6b819c2c27b53d4f6bd
# -a----          4/3/2025   7:08 PM         140663 fc2874da636f5d1df3ca9a7af5a49293
#
#
# Directory: D:\lms\server\utils
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a----         2/10/2025   1:15 PM            875 cloudinary.js
# -a----          4/2/2025  11:55 AM           1276 generateToken.js
# -a----         2/10/2025  11:29 AM            102 multer.js
# -a----          4/4/2025   1:57 PM           1107 notifications.js
# -a----          4/2/2025  11:48 AM           1910 zoom.js

# %% [markdown]
# #### Conclusion
#
# Iterators and generators are powerful tools in Python for creating and handling sequences of data efficiently. Iterators provide a way to access elements sequentially, while generators allow you to generate items on the fly, making them particularly useful for handling large datasets and infinite sequences. Understanding these concepts will enable you to write more efficient and memory-conscious Python programs.
